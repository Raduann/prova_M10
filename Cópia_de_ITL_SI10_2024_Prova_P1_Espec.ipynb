# %% [markdown]
# <center>
#   <img src="https://www.inteli.edu.br/wp-content/uploads/2022/04/28103439/Logo-Container.png" />
# </center>

# %% [markdown]
# # `[SI10-2024-P1]` - Prova Prática

# %% [markdown]
# Sistemas de Informação - Módulo 10 - Turma 4

# %% [markdown]
# **Nome**: *Raduan Muarrek*

# %% [markdown]
# **ANTES DE PROSSEGUIR FAÇA UMA CÓPIA DESTE NOTEBOOK**

# %% [markdown]
# ----

# %% [markdown]
# ## Contexto

# %% [markdown]
# Uma plataforma online, que atua na venda de produtos, deseja otimizar sua interface para melhorar a experiência do usuário e aumentar as taxas de conversão. Recentemente, a empresa implementou um redesign de sua página web, e os registros dessa mudança estão detalhados nos dados coletados desde então. As variáveis registradas diariamente incluem o número de visitantes únicos, sessões, taxa de rejeição, páginas por sessão, principais origens do tráfego, tipos de dispositivos usados, eventos ocorridos, taxa de conversão e o tempo médio de sessão.
#
# Com base nesses dados, a empresa considera realizar uma mudança similar para otimizar ainda mais sua plataforma. Antes de proceder, a equipe deseja empregar simulações de Monte Carlo para avaliar os possíveis impactos de um novo redesign na taxa de conversão, tempo médio de sessão e taxa de rejeição, utilizando análises estatísticas para prever tendências futuras e ajustar estratégias de maneira informada. Essa abordagem visa garantir que as decisões tomadas maximizem as taxas de conversões, fundamentais para o sucesso contínuo da plataforma.

# %% [markdown]
# ## Importação do dataset e das bibliotecas

# %%
# Importação do dataset
# https://drive.google.com/file/d/1K_2ZDsrhheRDKoHN2ynfLCPGPFiS2CZr/view?usp=drive_link
# !gdown 1K_2ZDsrhheRDKoHN2ynfLCPGPFiS2CZr
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1K_2ZDsrhheRDKoHN2ynfLCPGPFiS2CZr
# To: /content/ITL-SI10-2024-P1-dataset.csv
# 100% 7.03k/7.03k [00:00<00:00, 16.7MB/s]

# %%
# Importação das bibliotecas
import pandas as pd

# Transforma o dataset em DataFrame Pandas
df = pd.read_csv('ITL-SI10-2024-P1-dataset.csv')
print(df.head())
# Out:
#          Data  Visitantes Únicos  Sessões  Taxa de Rejeição (%)  \
# 0  2023-01-01              113.0    126.0             50.496714
# 1  2023-01-02               90.0    157.0             49.438007
# 2  2023-01-03               92.0    185.0             49.800231
# 3  2023-01-04              130.0    206.0             50.251843
# 4  2023-01-05              123.0    155.0             48.070931
#
#    Páginas por Sessão Principais Origens do Tráfego Dispositivos  Eventos  \
# 0            1.834201                        Direto      Desktop        8
# 1            1.955760                        Social      Desktop        5
# 2            2.285052                        Direto      Desktop        9
# 3            2.325464                          Pago       Mobile        6
# 4            2.267006                        Direto      Desktop        6
#
#    Taxa de Conversão (%)  Tempo Médio de Sessão (minutos)
# 0               1.952083                         5.395516
# ...

# %%
df.head()
# Out:
#    Visitantes Únicos  Sessões  Taxa de Rejeição (%)  Páginas por Sessão  \
# 0              113.0    126.0             50.496714            1.834201
# 1               90.0    157.0             49.438007            1.955760
# 2               92.0    185.0             49.800231            2.285052
# 3              130.0    206.0             50.251843            2.325464
# 4              123.0    155.0             48.070931            2.267006
#
#   Principais Origens do Tráfego Dispositivos  Eventos  Taxa de Conversão (%)  \
# 0                        Direto      Desktop        8               1.952083
# 1                        Social      Desktop        5               2.066180
# 2                        Direto      Desktop        9               2.058858
# 3                          Pago       Mobile        6               2.134617
# 4                        Direto      Desktop        6               2.420236
#
#    Tempo Médio de Sessão (minutos)
# ...

# %% [markdown]
# ## Questões

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#from matplotlib import pyplot as plt
#df['Páginas por Sessão'].plot(kind='hist', bins=20, title='Páginas por Sessão')
#plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
#from matplotlib import pyplot as plt
#df['Taxa de Rejeição (%)'].plot(kind='hist', bins=20, title='Taxa de Rejeição (%)')
#plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
#from matplotlib import pyplot as plt
#df['Sessões'].plot(kind='hist', bins=20, title='Sessões')
#plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
#from matplotlib import pyplot as plt
#df['Visitantes Únicos'].plot(kind='hist', bins=20, title='Visitantes Únicos')
#plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
#from matplotlib import pyplot as plt
#df.plot(kind='scatter', x='Visitantes Únicos', y='Sessões', s=32, alpha=.8)
#plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
#df.plot(kind='scatter', x='Taxa de Conversão (%)', y='Dispositivos', s=32, alpha=.8)
#plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
#plt.subplots(figsize=(8, 8))
#df_2dhist = pd.DataFrame({
#    x_label: grp['Dispositivos'].value_counts()
#    for x_label, grp in df.groupby('Taxa de Conversão (%)')
#})
#sns.heatmap(df_2dhist, cmap='viridis')
#plt.xlabel('Taxa de Conversão (%)')
#_ = plt.ylabel('Dispositivos')

# %%
#plt.subplots(figsize=(8, 8))
#df_2dhist = pd.DataFrame({
#    x_label: grp['Dispositivos'].value_counts()
#    for x_label, grp in df.groupby('Principais Origens do Tráfego')
#})
#sns.heatmap(df_2dhist, cmap='viridis')
#plt.xlabel('Principais Origens do Tráfego')
#_ = plt.ylabel('Dispositivos')

# %% [markdown]
# ### Questão 1

# %% [markdown]
# **Análise Exploratória de Dados**: Faça a exploração dos dados, utilizando gráficos interativos. Identifique correlações entre as variáveis e apresente essas relações em uma matriz de correlação focada nas variáveis mais relevantes para a conversão de vendas.

# %% [markdown]
# Preferi fazer algo enxuto mas que responda a questão, só coloquei aquilo que acho que faz sentido de fato. Mas se quiser mais gráficos que usei para fazer o estudo eles estão acima, aí é so tirar o comentário.

# %%
df.groupby('Dispositivos').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# Comecaria minha análise entendendo quem é meu principal público alvo. A partir desse gráfico iria entender que existem mais usuários com desktop, pensando assim em dar prioridade para essa plataforma

# %%
#Principais correlações

novodf = df[['Páginas por Sessão', 'Tempo Médio de Sessão (minutos)', 'Taxa de Conversão (%)', 'Taxa de Rejeição (%)']]
novodf.corr()

#novodf = novodf.corr()
#axis_corr = sns.heatmap(
#novodf,
#vmin=-1, vmax=1, center=0,
#cmap=sns.diverging_palette(50, 500, n=500),
#square=True
#)
#plt.show()
# Out:
#                                  Páginas por Sessão  \
# Páginas por Sessão                         1.000000
# Tempo Médio de Sessão (minutos)            0.960547
# Taxa de Conversão (%)                      0.988983
# Taxa de Rejeição (%)                      -0.968120
#
#                                  Tempo Médio de Sessão (minutos)  \
# Páginas por Sessão                                      0.960547
# Tempo Médio de Sessão (minutos)                         1.000000
# Taxa de Conversão (%)                                   0.976846
# Taxa de Rejeição (%)                                   -0.982036
#
#                                  Taxa de Conversão (%)  Taxa de Rejeição (%)
# Páginas por Sessão                            0.988983             -0.968120
# Tempo Médio de Sessão (minutos)               0.976846             -0.982036
# Taxa de Conversão (%)                         1.000000             -0.974824
# ...

# %% [markdown]
# Não plotei o gráfico pois algumas correlações são tão expressivas que é difícil de diferenciar por cor.
# Mas analisando os números temos umas questões interessantes, muitas correlações extremamente altas!
# A hipótese que tirei daqui é que aqueles que convertem são aqueles que ficam mais tempo na página. Então o processo de conversão dificilmente é um processo rápido, mas um processo em que o usuário provavelmente fica tempos pesquisando e entendendo sobre a página.
# a correlação de tempo médio e página por sessão com taxa de conversão é 98% e 97%
# Enquanto a de taxa de rejeição é inversamente proporcional.
# Números MUITO expressivos.

# %%
df.plot(kind='scatter', x='Tempo Médio de Sessão (minutos)', y='Taxa de Conversão (%)', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# Somente para ilustrar a conclusão de cima!

# %%
import plotly.express as px
fig = px.bar(df, x='Dispositivos', y='Taxa de Conversão (%)')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# E para finalizar a análise, plotei esse gráfico onde existe um somatório de % de conversão por dispositivo, onde consigo ver que o Desktop tem um maior somatorio de conversão comparato com mobile e tablet, dando maior força há minha hipótese que quem compra é aquele que pesquisa mais, uma vez que temos a premissa que desktop a pessoa usa para pesquisar mais que alguem que usa mobile que seria algo mais conveniente e rápido de se usar.

# %% [markdown]
# ### Questão 2

# %% [markdown]
# **Simulação de Monte Carlo**: Implemente uma simulação de Monte Carlo para avaliar os possíveis efeitos de um novo redesign na plataforma. Analise como diferentes variáveis podem impactar os resultados e discuta os cenários que esta simulação pode prever, ajudando a empresa a tomar decisões mais informadas sobre o redesign.

# %%
taxa_rejeicao = np.random.choice([np.maximum(df['Taxa de Rejeição (%)']), np.minimum(df['Taxa de Rejeição (%)'])])

#Migué abaixo

# %% [markdown]
# Estou sem tempo e deu erro, mas faria as simulações e ligaria as variaveis pelas correlações encontradas na análise exploratória.

# %% [markdown]
# ### Questão 3

# %% [markdown]
# **Análise de Sensibilidade**: Realize uma análise de sensibilidade para examinar como alterações em diferentes variáveis de entrada afetam as previsões da taxa de conversão.

# %%
# Escreva sua resposta nesta seção (Você pode criar quantas células de texto e de código forem necessárias)

# %% [markdown]
# ## Entrega

# %% [markdown]
# Siga esses passos para entregar sua prova.
#
# 1. Crie um repositório no GitHub para essa entrega.
#
# 2. Submeta seu desenvolvimento neste repositório.
#
# 3. Garanta que o repositório é publicamente acessível (eliminatório).
#
# 4. No Google forms da prova, submeta a URL do repositório.
